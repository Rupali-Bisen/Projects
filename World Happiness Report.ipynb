# %% [markdown]
# # PRACTICE PROJECT - 1 -  WORLD HAPPINESS REPORT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#Importing the data set
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.keys()
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (158, 12)

# %% [raw]
# Here, in world happiness report data set there are total 158 rows and 12 columns.

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [raw]
# Here, Country and region are of object type.
# Happiness rank is integer value.
# Rest all the independent variables are float type values.
# Here, happiness score is oue target varibale with float type data.

# %%
#checking for any null values
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [raw]
# There are no null values in the data set.

# %% [markdown]
# # EDA

# %%
#Univariate Analysis_sdistribution plot
for i in df.columns:
    if(df[i].dtype == np.float64):
        plt.figure()
        sns.distplot(df[i])

# %% [raw]
# Standard error, Trust and Generosity has left skweness.
# Family , Health and Freddom is rightly skewed.

# %%
#Checking for Outliers
df.plot(kind='box',subplots=True,layout=(2,5))
# Out:
# Happiness Rank                      AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Happiness Score                  AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Standard Error                    AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# Economy (GDP per Capita)         AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Family                           AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Health (Life Expectancy)               AxesSubplot(0.125,0.125;0.133621x0.343182)
# Freedom                             AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Trust (Government Corruption)        AxesSubplot(0.44569,0.125;0.133621x0.343182)
# Generosity                          AxesSubplot(0.606034,0.125;0.133621x0.343182)
# Dystopia Residual                   AxesSubplot(0.766379,0.125;0.133621x0.343182)
# dtype: object

# %% [raw]
# From above box plot it can be observed that Standard error, family, Trust and Dystopia Residual has outliers.

# %%
#Bivariate analysis.
#Comparing Economy (GDP per Capita) with Trust (Government Corruption)
plt.figure(figsize=[10,6])
plt.title('Comparison between Economy (GDP per Capita) and Trust (Government Corruption)')
sns.scatterplot(df['Economy (GDP per Capita)'],df['Trust (Government Corruption)'],hue=df['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparison between Economy (GDP per Capita) and Trust (Government Corruption)'}, xlabel='Economy (GDP per Capita)', ylabel='Trust (Government Corruption)'>

# %% [raw]
# Countries having large economy and Trust have highest happiness score above value 6.4

# %%
#Comparing Family with Health (Life Expectancy)
plt.figure(figsize=[10,6])
plt.title('Comparison between Family and Health (Life Expectancy)')
sns.scatterplot(df['Family'],df['Health (Life Expectancy)'],hue=df['Happiness Score'],alpha=1,c=(1,0,1),edgecolors='g')
# Out:
# <AxesSubplot:title={'center':'Comparison between Family and Health (Life Expectancy)'}, xlabel='Family', ylabel='Health (Life Expectancy)'>

# %% [raw]
# Countries with happiness score more than 5 have more family and life expectancy.

# %%
#Comparing Generosity with Trust (Government Corruption)
plt.figure(figsize=[10,6])
plt.title('Comparison between Generosity and Trust (Government Corruption)')
sns.scatterplot(df['Generosity'],df['Trust (Government Corruption)'],hue=df['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparison between Generosity and Trust (Government Corruption)'}, xlabel='Generosity', ylabel='Trust (Government Corruption)'>

# %% [raw]
# From above comparison, it can be seen that generosity level is less compared to Trust.

# %%
#Comparing Dystopia Residual with Trust (Government Corruption)
plt.figure(figsize=[10,6])
plt.title('Comparison between Dystopia Residual and Trust (Government Corruption)')
sns.scatterplot(df['Dystopia Residual'],df['Trust (Government Corruption)'],hue=df['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparison between Dystopia Residual and Trust (Government Corruption)'}, xlabel='Dystopia Residual', ylabel='Trust (Government Corruption)'>

# %%
#Comparing Dystopia Residual with Freedom
plt.figure(figsize=[10,6])
plt.title('Comparison between Dystopia Residual and Freedom')
sns.scatterplot(df['Dystopia Residual'],df['Freedom'],hue=df['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparison between Dystopia Residual and Freedom'}, xlabel='Dystopia Residual', ylabel='Freedom'>

# %%
#Comparing Dystopia Residual with Economy (GDP per Capita)
plt.figure(figsize=[10,6])
plt.title('Comparison between Dystopia Residual and Economy (GDP per Capita)')
sns.scatterplot(df['Dystopia Residual'],df['Economy (GDP per Capita)'],hue=df['Happiness Score'])
# Out:
# <AxesSubplot:title={'center':'Comparison between Dystopia Residual and Economy (GDP per Capita)'}, xlabel='Dystopia Residual', ylabel='Economy (GDP per Capita)'>

# %%
#Multivariate Ananlysis
sns.pairplot(df,hue='Happiness Score')

# %%
df.plot(kind='density',subplots=True,layout=(2,5),sharex=False,legend=1,fontsize=1,figsize=(18,12))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
#Checking for correlation
cor=df.corr()
cor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %% [raw]
# From above correlation table it is observed that standard error variable has negative correlation with almost evet variable.
# Generosity ha negative correlation with Economy.
# Dystopia Residual has negative correlation with Trust and Generosity variable.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(cor,annot=True,linewidths=.5)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [raw]
# Target variable i.e. Happiness score has negative correlation with happiness rank, standard error.

# %%
#sepearting independent variable and target column
y=df['Happiness Score']
print(y)
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
x=df.iloc[:,4:]
print(x)
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 153         0.03464                   0.22208  0.77370
# 154         0.03656                   0.28665  0.35386
# 155         0.05015                   0.66320  0.47489
# 156         0.08658                   0.01530  0.41587
# 157         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
x.shape
# Out:
# (158, 8)

# %%
y.shape
# Out:
# (158,)

# %%
#importing libraries from sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
#finding out best random state

from sklearn.linear_model import LinearRegression
maxscore=0
maxRS=0
for i in range(1,110):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    score=r2_score(y_test,pred)
    if score>maxscore:
        maxscore=score
        maxRS=i
print('Best r2_score is : ',maxscore,'on random state :' ,maxRS)
# Out:
# Best r2_score is :  0.9999999571007488 on random state : 54

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=54)

# %%
x_train.shape
# Out:
# (110, 8)

# %%
y_train.shape
# Out:
# (110,)

# %%
x_test.shape
# Out:
# (48, 8)

# %%
y_test.shape
# Out:
# (48,)

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
lm.coef_
# Out:
# array([-8.19333111e-04,  1.00016162e+00,  9.99982484e-01,  9.99775242e-01,
#         9.99586679e-01,  9.99945080e-01,  1.00002442e+00,  1.00000513e+00])

# %%
lm.intercept_
# Out:
# 0.00018104870382984473

# %%
lm.score(x_train,y_train)
# Out:
# 0.9999999310336937

# %%
#predict the values

from sklearn.metrics import mean_squared_error, mean_absolute_error
pred=lm.predict(x_test)
print('Mean Absolute Error:',mean_absolute_error(y_test,pred))
print('Mean Squared Error:',mean_squared_error(y_test,pred))

print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Mean Absolute Error: 0.00021850827082783852
# Mean Squared Error: 6.712347152802006e-08
# root mean squared error: 0.00025908197839297903

# %%
#saving the file for deployment to client
import joblib
joblib.dump(lm,'World_Happiness_report.obj')
# Out:
# ['World_Happiness_report.obj']
