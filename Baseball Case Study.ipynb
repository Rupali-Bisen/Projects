# %%
#importing libraries
#pandas and numpy for data manipulation
import numpy as np
import pandas as pd

#matplotlib and seaborn for data visualization
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
#sns.set(font_scale = 2)


#importing warnings to ignore warnings
import warnings
warnings.filterwarnings('ignore')


#importing stats from scipy
from scipy import stats

# %%
#Loading the dataset
data=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

#Displaying top of dataset
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [raw]
# Dataset Description:
#     1.  W: Number of predicted wins(Output)
#     2.  R: Runs
#     3. AB: At Bats
#     4.  H: Hits
#     5. 2B: Doubles
#     6. 3B: Triples
#     7. HR: Homeruns
#     8. BB: Walks
#     9. SO: Strikeouts
#     10.SB: Stolen Bases
#     11.RA: Runs Allowed
#     12.ER: Earned Runs
#     13.ERA:Earned Run Average
#     14.CG:
#     15.SHO:Shutouts
#     16.SV: Saves
#     17. E: Errors

# %%
#Checking shape of data
print('Shape of Baseball dataset is :',data.shape)
# Out:
# Shape of Baseball dataset is : (30, 17)

# %% [raw]
#  Datset has 30rows and 17 columns with 'W' as output variable.

# %%
# Checking for info of dataset
print('Information of Baseball case study dataset:','\n')
data.info()
# Out:
# Information of Baseball case study dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [raw]
# 1. RangeIndex: 30 entries, 0 to 29 and Data columns (total 17 columns)
# 2. Memory usage of dataset is 4.1KB.
# 3. Datset donot have any null values.
# 4. All attributes are integer type, except for 'ERA' which is float type of data.

# %%
#Checking for unique values
data.apply(lambda x: len(x.unique()))
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
data.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [raw]
# All attributes are integer type, except for 'ERA' which is float type of data.

# %%
data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [raw]
# Dataset has no null values.

# %%
#statistical summary

data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [raw]
# 1. Mean and median for nearlly all attributes is same which shows data is near to normal distribution.
# 2. Minimum value of CG is 0
# 3. Lowest predictd win is 63 and highest is 100

# %%
#Visualization of describe function

plt.figure(figsize=(20,8))
sns.heatmap(data.describe(),annot=True,linecolor='white',fmt='.2f',linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
## Plotting distribution of wins using Histogram plot

plt.hist(data['W'])
plt.xlabel('Wins')
plt.title('Distribution of wins')
# Out:
# Text(0.5, 1.0, 'Distribution of wins')

# %%
### Exploratory Data Analysis
## Distribution plot
data.plot(kind='density',subplots=True,layout=(4,5),sharex=False,fontsize=1,figsize=(18,15))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
for i in data.columns:
    sns.distplot(data[i],rug=True, rug_kws={"color": "g"},
                  kde_kws={"color": "k", "lw": 3, "label": "KDE"},
                  hist_kws={"histtype": "step", "linewidth": 3,
                            "alpha": 1, "color": "g"})
    plt.figure()

# %% [raw]
# From above distribution and density plot, it is observed that data for all attributes is normally distributed. Slight skewness is observed in some of the attributes. We shall be checking of skewness in eacg attributes later on.

# %%
plt.figure(figsize=(15,15))

plt.subplot(531)
sns.scatterplot(x='R',y='AB',data=data,hue='W')
plt.title('Comparison of R with AB ')

plt.subplot(532)
sns.scatterplot(x='R',y='H',data=data,hue='W')
plt.title('Comparison of R with H ')


plt.subplot(533)
sns.scatterplot(x='AB',y='H',data=data,hue='W')
plt.title('Comparison of AB with H ')


plt.subplot(534)
sns.scatterplot(x='2B',y='3B',data=data,hue='W')
plt.title('Comparison of 2B with 3B ')

plt.subplot(535)
sns.scatterplot(x='HR',y='AB',data=data,hue='W')
plt.title('Comparison of HR with AB ')

plt.subplot(536)
sns.scatterplot(x='SO',y='BB',data=data,hue='W')
plt.title('Comparison of SO with BB ')


plt.subplot(537)
sns.scatterplot(x='ER',y='BB',data=data,hue='W')
plt.title('Comparison of ER with BB ')


plt.subplot(538)
sns.scatterplot(x='CG',y='SHO',data=data,hue='W')
plt.title('Comparison of CG with SHO ')

plt.subplot(539)
sns.scatterplot(x='SV',y='E',data=data,hue='W')
plt.title('Comparison of SV with E ')


plt.subplots_adjust(wspace = 0.2, hspace = 0.4,top = 1.5)
plt.show()

# %% [raw]
# Observations:
#     1. A very few outliers cab be observed which can be neglected.
#     2. Graph for almost all plot is linear .
#     3. With increasing 'H', 'W' also increases.
#     4. With the highest 'BB' score, the prediction of wins also increases.
#     5. Hughest predicted wins has less errors and more SV score.

# %%
##Checking for correlation of output variable with other attributes:
corr_matrix=data.corr()

# %%
#Graphical Visualization of correlation 
plt.figure(figsize=(20,8))
sns.heatmap(corr_matrix,annot=True,linecolor='white',fmt='.2f',linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
x=corr_matrix['W'].sort_values(ascending=False)
x
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [raw]
# 1.Target variable is highly positively correlated with attribute'SV' and highly negatively correlated with attribute 'ERA'.
#
# 2.target variable has very less correlation with attribute "H" & "CG".

# %%
plt.figure(figsize=(15,5))

x.drop(['W']).plot(kind='bar',color='r')

plt.xlabel('Feature',fontsize=14)
plt.ylabel('Correlation with target',fontsize=14)
plt.title('Correlation',fontsize=16)
plt.show()

# %%
###checking for outliers

#Checking for outliers for first 16 rows
data.boxplot(figsize=[20,7])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [raw]
# Data has very less outlier swhich can be neglected to prevent data loss. As outliers donot affect data much.

# %%
## Checking for skewness of data
data.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [raw]
# All the attributes has very less skewness below acceptable range of +/-0.5 except for attributes: R, H, CG, SHO,SV,E.
# Hence treating skewness for data accuracy.

# %%
## Treating skewness with log, sqrt or cbrt tranformation

data['R']=np.log(data['R'])
data['R'].skew()

### double log tranformation to remove skewness from 0.64 to below 0.5
data['R']=np.cbrt(data['R'])
data['R'].skew()

data['R']=np.log(data['R'])
data['R'].skew()

data['R']=np.cbrt(data['R'])
data['R'].skew()
# Out:
# 0.6540120518739654

# %% [raw]
# Skewness for attribute 'R' is reduced from 1.2 to 0.58. Removing skewness below this value leads to Nan values.

# %%
#Removing skewness for attribute 'H'
data['H']=np.log(data['H'])
data['H'].skew()
# Out:
# 0.6285536261591038

# %%
#double log tranformation
data['H']=np.log(data['H'])
data['H'].skew()
# Out:
# 0.6227003368936916

# %%
data['H']=np.cbrt(data['H'])
data['H'].skew()
# Out:
# 0.6207250206358366

# %%
data['H']=np.sqrt(data['H'])
data['H'].skew()
# Out:
# 0.6202307429777904

# %%
data['H']=np.log(data['H'])
data['H'].skew()
# Out:
# 0.6197362858264284

# %%
#Removing skewness for attribute 'SHO'
data['SHO']=np.cbrt(data['SHO'])
data['SHO'].skew()
# Out:
# -0.2802834063809521

# %%
#Removing skewness for attribute 'SV'
data['SV']=np.log(data['SV'])
data['SV'].skew()
# Out:
# 0.15058249970623516

# %%
#Removing skewness for attribute 'E'
data['E']=np.log(data['E'])
data['E'].skew()
# Out:
# 0.6300804690891397

# %%
#Removing skewness for attribute 'E'
data['E']=np.log(data['E'])
data['E'].skew()
# Out:
# 0.5695944968666948

# %%
#Removing skewness for attribute 'E'
data['E']=np.log(data['E'])
data['E'].skew()
# Out:
# 0.5290695668488631

# %%
#Removing skewness for attribute 'E'
data['E']=np.log(data['E'])
data['E'].skew()
# Out:
# 0.4294583980747559

# %%
#Checking for skewness fter removing 
data.skew()
# Out:
# W      0.047089
# R      0.654012
# AB     0.183437
# H      0.619736
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO   -0.280283
# SV     0.150582
# E      0.429458
# dtype: float64

# %% [raw]
# 1. Skewness removal for " CG" lead to null values. So keeping skewness for CG as it is.
# 2. Skewness for attribute 'R' is reduced from 1.2 to 0.58. Reducing below this gets nan values into the dataset.
# 3. Skewness for attribute "H" is reduced from 0.67 to 0.61
# 4. Skewness for attribute "SHO" is reduced from 0.56 to -0.28
# 5. Skewness for attribute "SV" is reduced from 0.65 to 0.15
# 6. Skewness for attribute "E" is reduced from 0.89 to 0.42

# %%
data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.pairplot(data,hue='W',palette='afmhot',size=1.4)

# %%
from sklearn.utils import shuffle
data_shuffled = shuffle(data)

data_shuffled = data_shuffled.reset_index(drop=True)

data_shuffled
# Out:
#       W         R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER  \
# 0    86  0.856628  5459  0.113555  278  26  230  486  1392  121  618  572
# 1    63  0.853073  5529  0.113649  272  37  130  387  1274   88  809  749
# 2    83  0.855558  5467  0.113434  277  44  156  439  1264   70  700  653
# 3    67  0.850955  5420  0.113538  251  18  100  471  1107   69  760  698
# 4    71  0.852574  5463  0.114031  236  40  120  375  1150  112  678  638
# 5   100  0.853852  5484  0.113750  288  39  137  506  1267   69  525  478
# 6    97  0.855324  5491  0.113364  272  30  171  567  1518   95  608  546
# 7    90  0.855120  5527  0.113451  295  17  177  488  1290   51  613  557
# 8    78  0.857217  5640  0.114624  294  33  161  478  1148   71  753  694
# 9    76  0.852921  5533  0.113708  260  27  136  404  1231   68  701  643
# 10   95  0.856469  5575  0.114640  300  42  139  383   973  104  641  601
# 11   88  0.857308  5511  0.114023  279  32  172  503  1233  101  733  680
# ...

# %%
#Splitting training and testing data

ds_x= data_shuffled.drop(['W'],axis=1)
y=data_shuffled['W']

# %%
#lets bring all features to a common scale

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_x)



x=pd.DataFrame(x,columns=ds_x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.757912 -0.826562 -0.720496  0.183611 -0.515731  2.121125  0.301276
# 1  -1.134429  0.183787 -0.515810 -0.153633  0.554654 -1.074945 -1.463595
# 2   0.188742 -0.711094 -0.983912  0.127403  1.235809 -0.243967 -0.536592
# 3  -2.261567 -1.389471 -0.757926 -1.333988 -1.294193 -2.033766  0.033871
# 4  -1.399895 -0.768828  0.319193 -2.177099  0.846578 -1.394552 -1.677518
# 5  -0.719398 -0.465723 -0.294762  0.745685  0.749270 -0.851220  0.657815
# 6   0.063818 -0.364688 -1.135924 -0.153633 -0.126500  0.235444  1.745261
# 7  -0.044486  0.154920 -0.946079  1.139136 -1.391501  0.427208  0.336930
# 8   1.071706  1.785913  1.612919  1.082929  0.165423 -0.084163  0.158660
# 9  -1.215395  0.241522 -0.386583 -0.828122 -0.418423 -0.883181 -1.160536
# 10  0.673694  0.847731  1.646340  1.420173  1.041193 -0.787299 -1.534902
# 11  1.120375 -0.076017  0.301390  0.239818  0.068115  0.267405  0.604334
# ...

# %% [raw]
# #Splitting training and testing data
#
# x= data.drop(['W'],axis=1)
# y=data['W']

# %%
print('Shape of x:',x.shape)
print('Shape of y:',y.shape)
# Out:
# Shape of x: (30, 16)
# Shape of y: (30,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
#Finding out best random state

from sklearn.linear_model import  LinearRegression
maxAccu=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best Accuracy is : ',maxAccu,'on random state :' ,maxRS)
# Out:
# Best Accuracy is :  0.8498680099130498 on random state : 85

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=84)

print('Shape of x_train:',x_train.shape)
print('Shape of x_test:',x_test.shape)
print('Shape of y_train:',y_train.shape)
print('Shape of y_test:',y_test.shape)
# Out:
# Shape of x_train: (21, 16)
# Shape of x_test: (9, 16)
# Shape of y_train: (21,)
# Shape of y_test: (9,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import Lasso,Ridge,BayesianRidge,ElasticNet,HuberRegressor,LinearRegression,LogisticRegression,SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
models = [['DecisionTree :',DecisionTreeRegressor()],
               ['RandomForest :',RandomForestRegressor()],
               ['KNeighbours :', KNeighborsRegressor(n_neighbors = 2)],
               ['SVM :', SVR()],
               ['AdaBoostClassifier :', AdaBoostRegressor()],
               ['GradientBoostingClassifier: ', GradientBoostingRegressor()],
               ['Xgboost: ', XGBRegressor()],
               ['Lasso: ', Lasso()],
               ['Ridge: ', Ridge(random_state=6)],
               ['BayesianRidge: ', BayesianRidge()],
               ['ElasticNet: ', ElasticNet()],
               ['HuberRegressor: ', HuberRegressor()]]

# %%
print("Mean Square Errors---->")
print('\n')

for name,model in models:
    model = model
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    print(name, (np.sqrt(mean_squared_error(y_test, predictions))))
# Out:
# Mean Square Errors---->
#
#
# DecisionTree : 12.25198396632607
# RandomForest : 8.608300903456177
# KNeighbours : 9.998611014647096
# SVM : 10.458953359846927
# AdaBoostClassifier : 8.52484770952816
# GradientBoostingClassifier:  11.910064899632445
# Xgboost:  8.221546090302951
# Lasso:  3.8657287237152076
# Ridge:  5.334750513254574
# BayesianRidge:  5.696271010811517
# ElasticNet:  5.369663681577768
# HuberRegressor:  7.6038724822460635

# %%
print("r2 Square/Accuracy Score----->")
print('\n')


for name,model in models:
    model = model
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    print(name, (r2_score(y_test, predictions))*100)
# Out:
# r2 Square/Accuracy Score----->
#
#
# DecisionTree : -64.88888888888889
# RandomForest : 21.62018888888889
# KNeighbours : 0.02777777777778212
# SVM : -9.38970538345334
# AdaBoostClassifier : 39.090740740740735
# GradientBoostingClassifier:  -27.72463058662884
# Xgboost:  32.40617988502426
# Lasso:  85.0561414346432
# Ridge:  71.54043696133006
# BayesianRidge:  67.55249657138833
# ElasticNet:  71.16671194674468
# HuberRegressor:  42.181123273741086

# %%
print('Cross_val_scores:')
print('\n')

names=[]
predictions=[]


for name,model in models:
    result=cross_val_score(model,x,y,cv=5,scoring='r2')
    predictions.append(result)
    names.append(name)
    result="%s : %f (%f)"%(name,result.mean()*100,result.std())
    print(result)
# Out:
# Cross_val_scores:
#
#
# DecisionTree : : -76.943704 (1.016888)
# RandomForest : : 20.006750 (0.395017)
# KNeighbours : : 7.529884 (0.502006)
# SVM : : -32.997428 (0.420487)
# AdaBoostClassifier : : -2.865715 (0.627668)
# GradientBoostingClassifier:  : -12.011211 (0.640500)
# Xgboost:  : -24.092019 (0.766734)
# Lasso:  : 74.975205 (0.164283)
# Ridge:  : 61.600728 (0.284303)
# BayesianRidge:  : 61.279846 (0.298536)
# ElasticNet:  : 63.446137 (0.226539)
# HuberRegressor:  : 50.198853 (0.366689)

# %% [raw]
# From above predictive analysis on MSE, r2_score and CV_scores:
#     1. DecisionTree,SVM ,GradientBoostingClassifier are very weak models as they have r2_score negative.
#     2. Lasso has the highest accuracy score 85.05%.

# %% [raw]
# Hence from above observations, Lasso is the best model with highest performance of all.
# Executing hyper parameter tuning to improve accuracy of model

# %% [raw]
# ### Performing Hyper parameter tuning to increse model performance of XGBoostregressor.
#
# from sklearn.model_selection import GridSearchCV
#
# param_tuning = {
#        'min_child_weight': [1, 5, 10],
#         'gamma': [0.5, 1, 1.5, 2, 5],
#         'subsample': [0.6, 0.8, 1.0],
#         'colsample_bytree': [0.6, 0.8, 1.0],
#         'max_depth': [3, 4, 5]
#     }
#
# #Create new XGB object
# XG_2 = XGBRegressor()
#
# #Use GridsearchCV
# GCV = GridSearchCV(estimator = XG_2,param_grid = param_tuning,n_jobs = -1,verbose = 1)
#
# #Fit the model
# best_model = GCV.fit(x,y)
#
# #checking for best parameters
# GCV.best_params_

# %% [raw]
# #Creating Final Model after hyperparameter tuning for XGBRegressor
#
# f_mod_xgb= XGBRegressor(
#         colsample_bytree = 0.8,
#         max_depth = 3,
#         gamma=0.5,
#         min_child_weight = 10,
#         subsample = 0.7)
#
#
# f_mod_xgb.fit(x_train, y_train)
#
# y_pred = f_mod_xgb.predict(x_test)
#
# print('root mean squared error for XGBRegressor:',np.sqrt(mean_squared_error(y_test,y_pred)))
#
# print('Model accuracy for XGBRegressor: ',r2_score(y_test, y_pred))

# %%
### Regularization :
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

parameters={'alpha':[.00001,.001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x,y)

clf.best_params_
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
#Creating Final Model after hyperparameter tuning for XGBRegressor

f_mod= Lasso(alpha=1,random_state=0)


f_mod.fit(x,y)

y_pred = f_mod.predict(x_test)

print('root mean squared error for XGBRegressor:',np.sqrt(mean_squared_error(y_test,y_pred)))

print('Model accuracy for XGBRegressor: ',r2_score(y_test, y_pred))
# Out:
# root mean squared error for XGBRegressor: 3.4279026225301714
# Model accuracy for XGBRegressor:  0.8824948361045077

# %% [markdown]
# ### After hyper parameter tuning, model accuracy of lasso increased from 85.05% to 88.24%.

# %%
#saving the model for deployment to client

import joblib

joblib.dump(f_mod,'baseball_lasso.obj')
# Out:
# ['baseball_lasso.obj']
