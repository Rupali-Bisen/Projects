# %%
#importing libraries
#pandas and numpy for data manipulation
import numpy as np
import pandas as pd

#matplotlib and seaborn for data visualization
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
#sns.set(font_scale = 2)


#importing warnings to ignore warnings
import warnings
warnings.filterwarnings('ignore')


#importing stats from scipy
from scipy import stats

# %%
#Loading the dataset
data=pd.read_csv(r'C:\Users\Csp\Downloads\WA_Fn-UseC_-HR-Employee-Attrition.csv')



#Display all columns of a dataframe
pd.set_option('display.max_columns', 35)

#Displaying top of dataset
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
#Checking shape of data
print('Shape of HR Analytics dataset is :',data.shape)
# Out:
# Shape of HR Analytics dataset is : (1470, 35)

# %% [raw]
# dataset has total 1,470 rows and 35 columns.

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#Checking for datatypes
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
data.apply(lambda x: len(x.unique()))
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [raw]
# Dividing datset into :
#     1. Nominal(catagorical) data type:['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Over18','OverTime']

# %%
# Checking for null values in the system

data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [raw]
# Dataset has no null values.

# %%
## Statistical Summary
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [raw]
# Observations:
#     1. All the value counts ar equal which means there is no null values in the data set.
#     2. Minimum age of employee is 18 and maximum is 60.
#     3. Employee count is constant. It doesn't impact much on the dataset . So in the further process we can drop that column.
#     4. Minimum monthly income of employee is 1009.00 and maximum is 19999.00.
#     5. Minimum MonthlyRate of employee is 2094.00 and maximum is 26999.00
#     6. Employee is a fresher with no prior companies and maximum companies employee has worked in is 9.
#     7. Minimum salary hike given to employee is 11.00% and maximum is 4.00%.
#     8. Performance rating of all the employees is either 3 or 4 pts.
#     9. Standard hours for every employee is also common that is 80Hrs.
#     10.Total working years of employee is starting from 0 yrs. to maximum.

# %%
#Visualization of describe function

plt.figure(figsize=(25,8))
sns.heatmap(data.describe(),annot=True,linecolor='white',fmt='.2f',linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
### Exploratory data ananlysis of nominal data type

Nominal_data_type:['Attrition','BusinessTravel','Department',
                   'EducationField','Gender','JobRole',
                   'MaritalStatus','Over18','OverTime']
    
plt.figure(figsize=(15,15))
    
plt.subplot(421)    
sns.countplot(x='Attrition',data=data)
print(data['Attrition'].value_counts())

plt.subplot(422) 
sns.countplot(x='BusinessTravel',data=data,hue='Attrition')
print(data['BusinessTravel'].value_counts())


plt.subplot(423) 
sns.countplot(x='Department',data=data,hue='Attrition')
print(data['Department'].value_counts())


plt.subplot(424) 
sns.countplot(x='Gender',data=data,hue='Attrition')
print(data['Gender'].value_counts())


plt.subplot(425) 
sns.countplot(x='MaritalStatus',data=data,hue='Attrition')
print(data['MaritalStatus'].value_counts())

plt.subplot(426) 
sns.countplot(x='Over18',data=data,hue='Attrition')
print(data['Over18'].value_counts())

plt.subplot(427) 
sns.countplot(x='OverTime',data=data,hue='Attrition')
print(data['OverTime'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# Male      882
# Female    588
# Name: Gender, dtype: int64
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
# Y    1470
# Name: Over18, dtype: int64
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
 plt.figure(figsize=(15,9))
plt.subplot(211) 
ax=sns.countplot(x='JobRole',data=data,hue='Attrition')
print(data['JobRole'].value_counts())


plt.subplot(212) 
sns.countplot(x='EducationField',data=data,hue='Attrition')
print(data['EducationField'].value_counts())
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [raw]
# Observations from visualization of nominal data:
#     1. Output variable 'Attrition' is imbalanced as it has more 'No' type attrition compared to 'Yes'.
#     2. Most of the employees travel rarely or frequently.
#     3. Dataset is given for employees working in three departments viz. sales, R&D, HR from which maximum of employees work in R&D.
#     4. More no. of male employees we have compared to females.
#     5. Most the employees have their marital status as marrid. Very few employees are divorced.
#     6. Only 40% of the employee do overtime.
#     7. Maximum workers work as Sales executive.
#     8. Maximum workers are from Life Sciences education background and medical.

# %%
## Visualozation of  Numerical data with target variable attrition
    
plt.figure(figsize=(20,20))

plt.subplot(311)    
sns.countplot(x='TotalWorkingYears',data=data,hue='Attrition')


plt.subplot(312)
sns.countplot(x='Age',data=data,hue='Attrition')


plt.subplot(313)
sns.countplot(x='YearsInCurrentRole',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='count'>

# %%
## Visualozation of  Numerical data with target variable attrition

plt.figure(figsize=(12,20))


plt.subplot(411)
sns.histplot(x='PercentSalaryHike',data=data,hue='Attrition')


plt.subplot(412)
sns.histplot(x='YearsSinceLastPromotion',data=data,hue='Attrition')


plt.subplot(413)
sns.histplot(x='NumCompaniesWorked',data=data,hue='Attrition')

plt.subplot(414)
sns.histplot(x='JobSatisfaction',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Count'>

# %% [raw]
# From above visulaization it is observed:
#     1. Attrition rate was highest in the starting 1 year of work and slowly decreases. After 10 years at work, attrition rate is highest and there after decreases to its minimum.
#     2. Attrition rate is highest between the age group 30-40.
#     3. Attrition rate is higher during starting years of job uptill 4-5 years and then it decreases.
#     4. Attrition rate is higher if percent salary hike is low below 15%.
#     5. If employees donot get hike above 20% they tend to leanve the company.
#     6. Employees usually work in the company for 1 year and tend to leave company with good salary hike in other company.

# %%
# histogram plot of monthly income wrt gender.
fig,ax = plt.subplots(figsize = (10,6))
sns.histplot(x= 'MonthlyIncome',hue = 'Gender',data=data, kde = True,ax=ax)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %% [raw]
# male employees have higher salaries compared to women.

# %%
#importing label encoder
from sklearn.preprocessing import LabelEncoder

#applying label encoding toconvert object type data to int type.
LE=LabelEncoder()
for i in data.columns:
    if data[i].dtypes=='object':
        data[i]=LE.fit_transform(data[i])

# %% [raw]
# #Applying ordinal encoding to convert all datatypes to float.
#
# from sklearn.preprocessing import OrdinalEncoder
# OE=OrdinalEncoder()
# for i in data.columns:
#     data[i]=OE.fit_transform(data[i].values.reshape(-1,1))

# %%
## Checking for data types after applying encoding

data.dtypes
# Out:
# Age                         int64
# Attrition                   int32
# BusinessTravel              int32
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int32
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# Over18                      int32
# OverTime                    int32
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# ...

# %%
# Density visualisation for all attributes

for i in data.columns:
    sns.distplot(data[i],rug=True, rug_kws={"color": "g"},
                  kde_kws={"color": "k", "lw": 3, "label": "KDE"},
                  hist_kws={"histtype": "step", "linewidth": 3,
                            "alpha": 1, "color": "g"})
    plt.figure()

# %% [raw]
# Density plot shows data has few skewness.
# So lest check for skewness.

# %%
data.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# ...

# %% [raw]
# ### Since the data is catagorical type, hence we shall not remove skewness

# %%
###checking for outliers

#Checking for outliers for first 16 rows
data.iloc[:,:17].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#Checking for outliers for remaining rows
data.iloc[:,17:].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [raw]
# dataset has no outliers.
# Since data is catagorical type. hence we shall not remove outliers.

# %%
##Checking for correlation of output variable with other attributes:
corr_matrix=data.corr()

# %%
#Graphical Visualization of correlation 
plt.figure(figsize=(22,20))
sns.heatmap(corr_matrix,annot=True,linecolor='white',fmt='.2f',linewidths=0.1)
# Out:
# <AxesSubplot:>

# %%
z=corr_matrix['Attrition'].sort_values(ascending=False)
z
# Out:
# Attrition                   1.000000
# OverTime                    0.246118
# MaritalStatus               0.162070
# DistanceFromHome            0.077924
# JobRole                     0.067151
# Department                  0.063991
# NumCompaniesWorked          0.043494
# Gender                      0.029453
# EducationField              0.026846
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# BusinessTravel              0.000074
# HourlyRate                 -0.006846
# EmployeeNumber             -0.010577
# PercentSalaryHike          -0.013478
# Education                  -0.031373
# YearsSinceLastPromotion    -0.033019
# RelationshipSatisfaction   -0.045872
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# JobInvolvement             -0.130016
# YearsAtCompany             -0.134392
# ...

# %%
plt.figure(figsize=(15,5))

z.drop(['Attrition']).plot(kind='bar',color='r')

plt.xlabel('Feature',fontsize=14)
plt.ylabel('Correlation with target',fontsize=14)
plt.title('Correlation',fontsize=16)
plt.show()

# %% [raw]
# 1.Data has highest positive correlation with overtime and hughest negative correlation with Total working years.
# 2.Dataset has no correlation with attributes: Employee count, over18 and Standard hours. So dropping these attributes will make data more feasible to handle.

# %%
## Dropping columns with less correlation

data.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis="columns", inplace=True)

# %%
#Splitting the data inrto train and test

ds_x=data.drop(['Attrition'],axis=1)
y=data['Attrition']

# %%
#lets bring all features to a common scale

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_x)



x=pd.DataFrame(x,columns=ds_x.columns)
x.head()
# Out:
#         Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0  0.446350        0.590048   0.742527    1.401512         -1.010909
# 1  1.322365       -0.913194  -1.297775   -0.493817         -0.147150
# 2  0.008343        0.590048   1.414363   -0.493817         -0.887515
# 3 -0.429664       -0.913194   1.461466   -0.493817         -0.764121
# 4 -1.086676        0.590048  -0.524295   -0.493817         -0.887515
#
#    Education  EducationField  EnvironmentSatisfaction    Gender  HourlyRate  \
# 0  -0.891688       -0.937414                -0.660531 -1.224745    1.383138
# 1  -1.868426       -0.937414                 0.254625  0.816497   -0.240677
# 2  -0.891688        1.316673                 1.169781  0.816497    1.284725
# 3   1.061787       -0.937414                 1.169781 -1.224745   -0.486709
# 4  -1.868426        0.565311                -1.575686  0.816497   -1.274014
#
#    JobInvolvement  JobLevel   JobRole  JobSatisfaction  MaritalStatus  \
# ...

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x_over,y_over=SM.fit_resample(x,y)

# %%
print('Shape of x_over:',x_over.shape)
print('Shape of y_over:',y_over.shape)
# Out:
# Shape of x_over: (2466, 30)
# Shape of y_over: (2466,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier,ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
#Finding out best random best state

maxAccu=0
maxRS=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x_over,y_over,test_size=.30,random_state=i)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred_train=dtc.predict(x_train)
    pred_test=dtc.predict(x_test)
    dtc_Accu=accuracy_score(y_test,pred_test)
    if dtc_Accu>maxAccu:
        maxAccu=dtc_Accu
        maxRS=i
print('Best Accuracy is : ',maxAccu*100,'on random state :' ,maxRS)
# Out:
# Best Accuracy is :  88.37837837837837 on random state : 73

# %%
x_train,x_test,y_train,y_test=train_test_split(x_over,y_over,test_size=.30,random_state=27)

# %%
models = [['DecisionTree :',DecisionTreeClassifier()],
               ['RandomForest :',RandomForestClassifier()],
               ['Extratrees :',ExtraTreesClassifier()],
               ['KNeighbours :', KNeighborsClassifier(n_neighbors = 2)],
               ['SVM :', SVC()],
               ['NB :' , GaussianNB()],
               ['AdaBoostClassifier :', AdaBoostClassifier()],
               ['GradientBoostingClassifier: ', GradientBoostingClassifier()],
               ['Xgboost: ', XGBClassifier()]]

# %%
print("Accuracy Score----->")
print('\n')


for name,model in models:
    model = model
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    print(name, (accuracy_score(y_test, predictions))*100)
# Out:
# Accuracy Score----->
#
#
# DecisionTree : 82.97297297297297
# RandomForest : 94.32432432432432
# Extratrees : 96.89189189189189
# KNeighbours : 89.45945945945945
# SVM : 91.08108108108108
# NB : 69.05405405405406
# AdaBoostClassifier : 89.72972972972974
# GradientBoostingClassifier:  92.43243243243244
# [21:16:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Xgboost:  93.51351351351352

# %% [raw]
# Extra Trees Classifier has the highest accuracyscore.

# %%
print("Confusion Matrix----->")
print('\n')


for name,model in models:
    model = model
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    print(name,'\n', (confusion_matrix(y_test, predictions))*100)
# Out:
# Confusion Matrix----->
#
#
# DecisionTree :
#  [[31000  8300]
#  [ 5000 29700]]
# RandomForest :
#  [[37600  1700]
#  [ 3400 31300]]
# Extratrees :
#  [[38000  1300]
#  [ 1200 33500]]
# KNeighbours :
#  [[31900  7400]
#  [  400 34300]]
# SVM :
#  [[35300  4000]
#  [ 2600 32100]]
# NB :
#  [[22100 17200]
#  [ 5700 29000]]
# AdaBoostClassifier :
#  [[35400  3900]
#  [ 3700 31000]]
# GradientBoostingClassifier:
#  [[37700  1600]
#  [ 4000 30700]]
# [21:17:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Xgboost:
#  [[37900  1400]
#  [ 3400 31300]]

# %%
print("Classification report----->")
print('\n')


for name,model in models:
    model = model
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    print(name,'\n', (classification_report(y_test, predictions))*100)
# Out:
# Classification report----->
#
#
# DecisionTree :
#                precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82       393
#            1       0.79      0.84      0.81       347
#
#     accuracy                           0.82       740
#    macro avg       0.82      0.82      0.82       740
# weighted avg       0.82      0.82      0.82       740
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82       393
#            1       0.79      0.84      0.81       347
#
#     accuracy                           0.82       740
#    macro avg       0.82      0.82      0.82       740
# weighted avg       0.82      0.82      0.82       740
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82       393
#            1       0.79      0.84      0.81       347
#
#     accuracy                           0.82       740
# ...

# %%
print('Cross_val_scores:')
print('\n')

names=[]
predictions=[]


for name,model in models:
    result=cross_val_score(model,x_over,y_over,cv=5)
    predictions.append(result)
    names.append(name)
    result="%s : %f (%f)"%(name,result.mean()*100,result.std())
    print(result)
# Out:
# Cross_val_scores:
#
#
# DecisionTree : : 86.460652 (0.061099)
# RandomForest : : 93.599297 (0.079426)
# Extratrees : : 97.000517 (0.017608)
# KNeighbours : : 90.186744 (0.011989)
# SVM : : 91.607033 (0.016376)
# NB : : 69.708633 (0.013469)
# AdaBoostClassifier : : 86.345600 (0.142157)
# GradientBoostingClassifier:  : 88.536926 (0.160342)
# [21:17:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:17:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [raw]
# ### Difference of r2_score and CV_score of model to find out best model.
# DecisionTree: 1.26
# RandomForest : 0.87
# Extratrees : 0.56
# KNeighbours : -0.54
# SVM : 1.41
# NB : 0.9
# AdaBoostClassifier : 3.98
# GradientBoostingClassifier: 4.22
# Xgboost: 3.23

# %% [raw]
# On checking cross validation score for treating overfitting or underfitting of data following observationa can be seen:
#     1. Difference is minimum for kNeighbors Classifier.
#   Hence, performing hyper parameter tuning on K-Nearest Neighbor Classifier.

# %%
### Improving accuracy of K-Nearest Neighbor using hyper parameter tuning

##importing library
from sklearn.model_selection import GridSearchCV


grid_params = { 'n_neighbors' : [5,7,9,11,13,15],
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan'],
              'leaf_size' : range(1,10),
              'p': [1,2]}

#Create new KNN object
knn_2 = KNeighborsClassifier()

#Use GridSearch
GCV = GridSearchCV(knn_2, grid_params, cv=5, scoring='accuracy')

#Fit the model
best_model = GCV.fit(x_over,y_over)

#checking for best parameters
GCV.best_params_
# Out:
# {'leaf_size': 1,
#  'metric': 'minkowski',
#  'n_neighbors': 5,
#  'p': 1,
#  'weights': 'distance'}

# %%
#Creating Final Model after hyperparameter tuning for KNN

f_mod_KNN= KNeighborsClassifier(n_neighbors=5,leaf_size=1,p=1,metric='minkowski',weights='distance')
f_mod_KNN.fit(x_train, y_train)

y_pred = f_mod_KNN.predict(x_test)

# Summary of the predictions made by the classifier
print('classification_report','\n',classification_report(y_test, y_pred))

print('-------------------------------------------------------------------------------------------------------------------')
print('Confusion matrix','\n',confusion_matrix(y_test, y_pred))

print('-------------------------------------------------------------------------------------------------------------------')
#Get accuracy. Note: In case of classification algorithms score method represents accuracy.
print('Accuracy score for KNeighborsClassifier is :',accuracy_score(y_pred,y_test))
print('-------------------------------------------------------------------------------------------------------------------')
scores = cross_val_score(f_mod_KNN, x, y, cv =5)
print('-------------------------------------------------------------------------------------------------------------------')

print('Model accuracy: ',np.mean(scores)*100)
# Out:
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.98      0.81      0.89       393
#            1       0.82      0.98      0.90       347
#
#     accuracy                           0.89       740
#    macro avg       0.90      0.90      0.89       740
# weighted avg       0.91      0.89      0.89       740
#
# -------------------------------------------------------------------------------------------------------------------
# Confusion matrix
#  [[320  73]
#  [  6 341]]
# -------------------------------------------------------------------------------------------------------------------
# Accuracy score for KNeighborsClassifier is : 0.8932432432432432
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Model accuracy:  84.6938775510204

# %% [markdown]
# ### After hyper parameter tuning, model accuracy with high performance is 84.69%.¶

# %%
## Checking fro AUC-ROC Score

y_prob=f_mod_KNN.predict_proba(x_test)[:,1] 
pred=f_mod_KNN.predict(x_test)
y_pred = np.where(y_prob > 0.5, 1, 0)
auc_roc=metrics.roc_auc_score(y_test,y_pred)
print('AUC-ROC score of LogisticRegression:',auc_roc)
print('-------------------------------------------------------------------------------------------------------------------')
fpr,tpr,thresholds=roc_curve(y_test,y_prob)
roc_auc = auc(fpr, tpr)

print('-------------------------------------------------------------------------------------------------------------------')
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='LogisticRegression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.axis('tight')
plt.plot(fpr,tpr, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.title('Receiver Operating Characteristic for KNeighborsClassifier')
plt.show()
# Out:
# AUC-ROC score of LogisticRegression: 0.8984791487926319
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### AUC-ROC score of model is 97%.

# %%
#saving the model for deployment to client

import joblib

joblib.dump(f_mod_KNN,'HR_analytics_knn.obj')
# Out:
# ['HR_analytics_knn.obj']
